# %% [markdown]
# Unit 2 Code Demo

# %%
import matplotlib.pyplot as plot
import numpy as np

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(5 * x)

# %%
plot.plot(x)
plot.plot(y)
plot.ylim([-1.1,1.1])
plot.xlabel("X axis")
plot.ylabel("Y axis")
plot.gca().set_facecolor('red')
plot.savefig('demo.png', facecolor='green')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
